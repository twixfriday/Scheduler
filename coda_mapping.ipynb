# %%
#pip install codaio

# %%
import os
os.environ["CODA_API_KEY"] = "48d23695-6f3a-4822-8bb7-5b66d230cc58"

# %%
from codaio import Document

doc_id = "FNKNx-WCXR"
doc = Document.from_environment(doc_id)

# %%
table = doc.get_table("grid-0BRlKYNNB-")  # or table_id

# %%
for col in table.columns():
    print(f"Name: {col.name} | ID: {col.id}")
# Out:
# Name: Telegram Manager Nickname | ID: c-KrdnfOalHd
# Name: JSON DATA | ID: c-VTA0UuTPNC
# Name: Open | ID: c-v8f52fAgn6
# Name: Delete | ID: c-DMgUvFqnOO
# Name: Telegram Manager ID | ID: c-_MWMwtlvCj
# Name: Promo Date | ID: c-aUCVsPWpLR
# Name: Promo Link | ID: c-WvfEYO0E-1
# Name: Rate | ID: c-1Hicf1AWsx
# Name: Currency | ID: c-wWX3WXLdxt
# Name: Parsing Date | ID: c-AE1vTTmEvQ
# Name: Duplicate | ID: c-vqosyqsPQR
# Name: Track Title | ID: c-S2fnCDCBSa
# Name: Artist Name | ID: c-w0s5s8glCA
# Name: Platform from Link | ID: c-sZWO6BS67x
# Name: Clean Link | ID: c-5RSVejCbVd
# Name: Get Instagram Data | ID: c-2mV6LG1-_u
# Name: Spotify Track Title | ID: c-sgDf8FAb3G
# Name: Spotify Artist Name | ID: c-4tX3QHoP-C
# Name: Spotify ISRC | ID: c-rEv85X7pmh
# Name: Spotify UPC | ID: c-SbrATeqr3l
# Name: Raw Track Title | ID: c-55_SsQlNw0
# Name: Raw Artist Name | ID: c-chaM3iNPS9
# Name: SP PARSE JSON | ID: c-qc_dkGjc_U
# Name: Get Spotify Data | ID: c-rBk0vFXg6g
# Name: Spotify JSON Data | ID: c-rdVg6EBA1e
# Name: Get YouTube Data | ID: c-Nq4mbDJ8ci
# Name: Video ID | ID: c-ceEVdKI4WL
# Name: Get TikTok Data | ID: c-fucyWGO5aR
# Name: New Row | ID: c-8OK9ca6XjI
# Name: Music Recognition Data | ID: c-16B_sfLQQT
# Name: AudD | ID: c-200_U9Sl1p
# Name: IG PARSE JSON | ID: c-8XWll5JIU2
# Name: TK PARSE JSON | ID: c-ECKQl9AcU0
# Name: YT PARSE JSON | ID: c-x-X1SgPDyc
# Name: Get All Data | ID: c-fl3ivnzAXK
# Name: MRD Parse JSON | ID: c--Wgd73a3zi
# Name: Promo Platform | ID: c-BVKwkuMCJE
# Name: Snapshots | ID: c-nbptIY-9DL
# Name: Add Snapshot | ID: c-XEjcBPZcyX
# Name: Views | ID: c-q3r37NO6Du
# Name: Likes | ID: c-Fso63ZRm1z
# Name: Comments | ID: c-XihF4cDet3
# Name: Number of snapshots | ID: c-xwAye0mXY5
# Name: Profile ID | ID: c-LfHMj2Z4Xt
# Name: Profile Name | ID: c-GSVdJwHq-m
# Name: Scrape | ID: c-vvtOE67z9n
# Name: Permanent Video Link | ID: c-sQ898w-LtU
# Name: Scrape Data | ID: c-cbiDhNl6PG
# Name: Original Sound | ID: c-ur7CwVVBU9
# Name: MRD Success | ID: c-TArNbOyH0T
# Name: MRD Failure | ID: c-C9Wb0Zdg1h
# Name: Shares | ID: c-eki3AgZ28b
# Name: Shazam | ID: c-r9zK3kPJZp
# Name: Release Date From JSON | ID: c-Plo7Q7bNT3
# Name: Last Snapshot Date | ID: c-8j4B0XSTGQ
# Name: D3 | ID: c-lBr6heVU9m
# Name: D7 | ID: c-oDQQfvz11E
# Name: D30 | ID: c-6wyPcCTgj0
# Name: Periodic Snapshot | ID: c-touyPivxe2

# %%
# Then upload table data to DataFrame
df = pd.DataFrame(table.to_dict())
print(df.head())

# %%
df = df[df['Duplicate'] == False]

# %%
df['Duplicate'].unique()
# Out:
# array([False])

# %%
df_report = df[["Telegram Manager Nickname",
                "Raw Artist Name",
                "Raw Track Title",
                "Spotify Artist Name",
                "Spotify Track Title",
                "Permanent Video Link",
                "Profile Name",
                "Promo Date",
                "Rate",
                "Views",
                "Likes",
                "Comments",
                "Shares",
                "Parsing Date",
                "Duplicate"]]

# %%
df_report['Parsing Date'] = pd.to_datetime(df_report['Parsing Date'])
df_report['Parsing Date'] = df_report['Parsing Date'].dt.strftime('%d.%m.%Y')
df_report['Promo Date'] = pd.to_datetime(df_report['Promo Date'])
df_report['Promo Date'] = df_report['Promo Date'].dt.strftime('%d.%m.%Y')
# Out:
# /tmp/ipython-input-1881255255.py:1: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_report['Parsing Date'] = pd.to_datetime(df_report['Parsing Date'])
# /tmp/ipython-input-1881255255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['Parsing Date'] = pd.to_datetime(df_report['Parsing Date'])
# /tmp/ipython-input-1881255255.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['Parsing Date'] = df_report['Parsing Date'].dt.strftime('%d.%m.%Y')
# /tmp/ipython-input-1881255255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['Promo Date'] = pd.to_datetime(df_report['Promo Date'])
# /tmp/ipython-input-1881255255.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['Promo Date'] = df_report['Promo Date'].dt.strftime('%d.%m.%Y')

# %%
df_report
# Out:
#      Telegram Manager Nickname            Raw Artist Name  \
# 0                   kulkristii                    UdieNnx
# 1                   kulkristii                    UdieNnx
# 2                   mexiko_dro                    UdieNnx
# 3                   mexiko_dro                    UdieNnx
# 4                   mexiko_dro  heapper & DJ JUAN & Mc Rd
# ...                        ...                        ...
# 6343             uglyandcringe   GMBTW & kvxrtvl & DJ TSF
# 6344             uglyandcringe   GMBTW & kvxrtvl & DJ TSF
# 6345             uglyandcringe                    KXZINVK
# 6346             uglyandcringe                    KXZINVK
# 6347             uglyandcringe           askat & TEENWXVE
#
#                               Raw Track Title      Spotify Artist Name  \
# 0                                   ACIDO III                  UdieNnx
# 1                          ACIDO III - Slowed                  UdieNnx
# 2                          ACIDO III - Slowed                  UdieNnx
# 3                          ACIDO III - Slowed                  UdieNnx
# 4     MONTAGEM INDEFERENÇA 1.0 - Super Slowed  heapper, DJ JUAN, Mc Rd
# ...                                       ...                      ...
# 6343                              MTG VAI VAI   GMBTW, kvxrtvl, DJ TSF
# 6344                     MTG VAI VAI - Slowed   GMBTW, kvxrtvl, DJ TSF
# 6345    MONTAGEM COSMOESTRELAS - Super Slowed                  KXZINVK
# 6346          MONTAGEM COSMOESTRELAS - Slowed                  KXZINVK
# 6347                                   HUMBLE          askat, TEENWXVE
#
#                           Spotify Track Title  \
# 0                                   ACIDO III
# 1                          ACIDO III - Slowed
# 2                          ACIDO III - Slowed
# 3                          ACIDO III - Slowed
# 4     MONTAGEM INDEFERENÇA 1.0 - Super Slowed
# ...                                       ...
# 6343                              MTG VAI VAI
# 6344                     MTG VAI VAI - Slowed
# 6345    MONTAGEM COSMOESTRELAS - Super Slowed
# 6346          MONTAGEM COSMOESTRELAS - Slowed
# 6347                                   HUMBLE
#
#                                    Permanent Video Link Profile Name  \
# 0     https://www.tiktok.com/@perigon66/video/756663...    perigon66
# 1     https://www.tiktok.com/@perigon66/video/756655...    perigon66
# 2     https://www.tiktok.com/@anikixdd/video/7565888...     anikixdd
# 3     https://www.tiktok.com/@anikixdd/video/7565912...     anikixdd
# 4     https://www.tiktok.com/@fut.vitin2_/video/7564...  fut.vitin2_
# ...                                                 ...          ...
# 6343
# 6344
# 6345
# 6346
# 6347
#
#       Promo Date Rate  Views Likes Comments Shares Parsing Date
# 0     29.10.2025   16   1709   132        3      2   29.10.2025
# 1     29.10.2025   16   6303   482        4     28   29.10.2025
# 2     27.10.2025   35  33700  2719       23     86   29.10.2025
# 3     27.10.2025   35  51400  5739       23    183   29.10.2025
# 4     22.10.2025   10  10500  1926       10     24   29.10.2025
# ...          ...  ...    ...   ...      ...    ...          ...
# 6343  16.09.2025   10                                16.09.2025
# 6344  16.09.2025   10                                16.09.2025
# 6345  16.09.2025   10                                16.09.2025
# 6346  16.09.2025   10                                16.09.2025
# 6347  16.09.2025   10                                16.09.2025
#
# [6348 rows x 14 columns]

# %%
import gspread
from google.colab import auth
auth.authenticate_user()

import google.auth
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from gspread_dataframe import set_with_dataframe


creds, _ = google.auth.default()

gc = gspread.authorize(creds)

spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1O-fYK3CywWpZ__YDVx6119Rw9Pe4NHaBob13MXBAVlk/edit?pli=1&gid=117213402'
sh = gc.open_by_url(spreadsheet_url)

worksheet = sh.get_worksheet(0)

set_with_dataframe(worksheet, df_report)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git config --global user.email "twixfriday@gmail.com"
# !git config --global user.name "twixfriday"

# %%
# Out:
# [Errno 2] No such file or directory: 'scheduler'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git clone https://github.com/twixfriday/scheduler.git
# Out:
# Cloning into 'scheduler'...
# warning: You appear to have cloned an empty repository.

# %%
# !cp /content/coda_mapping.ipynb /content/scheduler/
# Out:
# cp: cannot stat '/content/coda_mapping.ipynb': No such file or directory

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/coda_mapping.ipynb /content/scheduler/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/coda_mapping.ipynb': No such file or directory
